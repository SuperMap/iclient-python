# %%
import iclientpy as icp
import pandas as pd

# %%
map= icp.MapView(zoom=3)

# %%
df=pd.read_csv("mapvdata.csv")
df=df.reindex(df.index)
df["lng"] = pd.to_numeric(df["lng"],errors='coerce')
df["lat"] = pd.to_numeric(df["lat"],errors='coerce')
df["value"] = pd.to_numeric(df["value"],errors='coerce')

# %%
data=icp.convert_data_frame_to_dataset(data=df,lng_key='lng',lat_key='lat',value_key='value')

# %%
map_v_option=icp.MapvOptions(fill_style="#3732FA",shadow_color='#FFFA32',shadow_blur=20,size=50,label_show=True,label_fill_style='white',global_alpha=0.5)

# %%
layer=icp.MapVLayer(data_set=data,map_v_options=map_v_option)

# %%
map.add_layer(layer)

# %%
map
# Out:
# MapView(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[34.53938423, 108.92825141], default_tiles=CloudTileLayer(options=['attribution', 'detect_retina', 'map_name', 'max_zoom', 'min_zoom', 'opacity', 'tile_size', 'type']), layers=(CloudTileLayer(options=['attribution', 'detect_retina', 'map_name', 'max_zoom', 'min_zoom', 'opacity', 'tile_size', 'type']), MapVLayer(data_set=[{'geometry': {"coordinates": [117.6516476632447, 24.79141797359827], "type": "Point"}, 'count': 14.491465292723884}, {'geometry': {"coordinates": [115.40463990328631, 29.776387718326674], "type": "Point"}, 'count': 14.067846279906584}, {'geometry': {"coordinates": [102.83591325407131, 37.78320449322058], "type": "Point"}, 'count': 3.380951276555082}, {'geometry': {"coordinates": [114.20008296364172, 27.563277919153453], "type": "Point"}, 'count': 4.2453189035545567}, {'geometry': {"coordinates": [113.92464934805594, 35.98911800665196], "type": "Point"}, 'count': 21.103790384410281}, {'geometry': {"coordinates": [119.292562103013, 30.61882487736657], "type": "Point"}, 'count': 14.262399399002119}, {'geometry': {"coordinates": [120.17181966131152, 30.86242933169452], "type": "Point"}, 'count': 2.2817546411077521}, {'geometry': {"coordinates": [114.99508687747921, 30.309237141445852], "type": "Point"}, 'count': 17.939879377186486}, {'geometry': {"coordinates": [110.44259020913564, 18.389085140603576], "type": "Point"}, 'count': 13.537176389113732}, {'geometry': {"coordinates": [103.61527578455856, 36.606700733608], "type": "Point"}, 'count': 17.02182917106067}, {'geometry': {"coordinates": [119.43087304165206, 30.49979318547299], "type": "Point"}, 'count': 12.56430783260339}, {'geometry': {"coordinates": [89.42944535075941, 43.7481946469627], "type": "Point"}, 'count': 15.837689734938133}, {'geometry': {"coordinates": [115.5259234257038, 39.14143538458803], "type": "Point"}, 'count': 3.7085734422771011}, {'geometry': {"coordinates": [115.45041470138744, 31.71092085201672], "type": "Point"}, 'count': 1.4915123019361354}, {'geometry': {"coordinates": [107.2250883144926, 29.948791348668827], "type": "Point"}, 'count': 6.0202441875508228}, {'geometry': {"coordinates": [104.85724452944154, 30.98591328728362], "type": "Point"}, 'count': 11.263702310280054}, {'geometry': {"coordinates": [114.72228904974293, 27.957258344536648], "type": "Point"}, 'count': 24.253018808115392}, {'geometry': {"coordinates": [104.16682633037209, 26.911480114426052], "type": "Point"}, 'count': 3.7230848808257648}, {'geometry': {"coordinates": [108.60975976793728, 20.73064417895678], "type": "Point"}, 'count': 28.179407979252943}, {'geometry': {"coordinates": [119.14291799097226, 28.04149166252801], "type": "Point"}, 'count': 26.191097419096323}, {'geometry': {"coordinates": [104.64422368487114, 29.325731816308828], "type": "Point"}, 'count': 10.501144927647381}, {'geometry': {"coordinates": [113.7327616315568, 29.264471122449564], "type": "Point"}, 'count': 29.979261390555763}, {'geometry': {"coordinates": [123.15869167072469, 42.335209199582884], "type": "Point"}, 'count': 0.59660885188531632}, {'geometry': {"coordinates": [111.65585285286308, 42.63717565827404], "type": "Point"}, 'count': 22.437067545403519}, {'geometry': {"coordinates": [111.1299292049502, 39.26859763715691], "type": "Point"}, 'count': 8.4229608032511063}, {'geometry': {"coordinates": [118.19802934946397, 26.415751416519928], "type": "Point"}, 'count': 5.1017553280157975}, {'geometry': {"coordinates": [86.87661607010298, 42.317919239789035], "type": "Point"}, 'count': 12.844419847425394}, {'geometry': {"coordinates": [124.68307581937314, 46.587029637794856], "type": "Point"}, 'count': 2.7079765633971031}, {'geometry': {"coordinates": [120.39447130952476, 25.84289912910175], "type": "Point"}, 'count': 3.0663968998567488}, {'geometry': {"coordinates": [124.91510973721226, 43.489 ...

# %%
layer.interact()
# Out:
# VBox(children=(IntSlider(value=50, continuous_update=False, description='大小:', layout=Layout(width='350px')), FloatSlider(value=0.5, continuous_update=False, description='透明度:', layout=Layout(width='350px'), max=1.0, readout_format='.1f'), ColorPicker(value='#FFFA32', description='描边颜色：', layout=Layout(width='350px')), ColorPicker(value='#3732FA', description='填充颜色：', layout=Layout(width='350px')), IntSlider(value=20, continuous_update=False, description='投影模糊级数:', layout=Layout(width='350px'))))
